# %%
using Plots

# %% [markdown]
# # 名词释义
#
# |term|frequency|definition|
# |--|--|
# |抽样误差|1||
# |检验效能|1||

# %% [markdown]
# # 简答题
#
#
# ### (11级临五) 说明试验设计中为何要遵循随机对照原则
#
# ### (11级临五) 总体均数的95%置信区间表明总体参数有95%的可能落在区间里，辨析这句话
#
# ### (11级临五) 为什么P＞0.05时不能接受H0
#
# ### (11级临五) 假设检验的两类错误含义和关系
#
# ### (09级临八)  是考poisson分布，二项分布和正态分布之间的关系
#
# ### (09级临八) 给出假设检验的一般步骤，说出假设检验的原理和基本思想
#
# ### (09级临八) 说说医学正常值和可信区间的有神马区别
#
# ### (09级临八) 随机区组设计里，若分2组，f检验能不能代替t检验，说理由
#
# ### (09级临八) 给一个实例，说明为什么用单侧检验是不合理的
#
# ### (08级临五) （数据记不清了）分别给了健康成年女性的红细胞数和血红蛋白的均数与方差，问是否能说明血红蛋白的变异程度大于红细胞数的变异程度？为什么
#
# ### (08级临五) 标准化的目标及基本思想，有哪些标准化的方法
#
# ### (08级临五) 样本均数与总体均数的比较、完全随机设计的总体均数比较以及配对设计的t检验的条件各是什么?
#
# ### (08级临五) 非参检验与参数检验相比的优缺点各是什么，以多组独立样本资料为例说下参数检验的步骤
#
# ### (03级临床) 两个独立样本（符合t检验的要求）进行t检验，得到t＝5，已知t远远大于t界值表中0.01所对应的数值，能否认为是一个小概率事件，为什么？
#
# ### (03级临床) 判断三个独立样本差别是否有统计学意义，某同学对其进行两两t检验，（样本都符合检验条件），问这种做法有什么缺陷？应当如何改进？
#
# ### (03级临床) 同一计量资料，用方差分析和秩和检验得到的结果不同，应该选择那一种方法？
#
# ### (03级临床) 对于等级资料，为什么不能用卡方检验，而应该选择秩和检验？
#
# ### (03级临床) 配对t检验，成组t检验以及大样本的u检验是否需要满足方差齐性？为什么？
#
# ### 山区和平原地区20到30岁男性红细胞的水平是否有差别；条件：两者的均数，标准差，以及例数都给出；求：变异系数，正常值范围，两者的红细胞是否有差别
#
# ### (03级临床) 两个独立样本的t检验（要吧公式背熟）
#
# ### (03级临床) 配对四个表资料的卡方检验，给出一组数据，要会制成配对的四个表
#
# ### (03级临床) 观察宫内放置节育环对妇女的影响；问：题中的方法是否有缺陷？为什么？如果让你来设计试验，应该怎么做？
#
# ### 标准差与标准误的联系与区别
#
# ### I类错误与II类错误的联系与区别
#
# ### 线形相关与线形回归的联系与区别

# %% [markdown]
# # 计算题
#
# ### (11级临五) 某研究单位想要知道新配方的不良反应率是否低于原配方。已知原配方的不良反应率0.01，现在有200名患者采用新配方治疗，无人产生不良反应。问新配方的不良反应率是否低于原配方。
#
# ### (11级临五) 给出了t分布自由度34-37的界值表，应用题
#
# ### (11级临五) Fisher检验应用题
#
# ### (09级临八) 5个10ml样本 培养后菌落分别为14、15、16、17、19给出1ml样本平均细菌数的95%可信区间
#
# ### (09级临八) 2样本间t检验的一般步骤……
#
# ### (09级临八) 考了一个单因素方差分析的一般步骤
#
# ### (08级临五) 题干是某种疾病治疗前后白细胞数的资料，9对治疗前后的数据，问治疗前后白细胞数有无差异.（配对t）
#
# ### (08级临五) 题目背景是注射不同剂量ISR对ATP酶的影响，给了4组不同注射剂量后计算好ATP酶的均数和标准差，题目中进行两两t检验来比较影响。问：
# - 题目中属于那种设计？（随机区组设计）
# - 题中的统计分析方法可行吗？为什么？
# - 写出可行的统计分析方法的步骤，不用计算
#
# ### (08级临五) 给了两组独立的数据，问都可以用什么方法检验它们的均值是否有差异？选择一种写出计算步骤，不用计算。

# %% [markdown]
# # 复习建议
#
# 1. 统计学怎么复习？
# 以本为本，课本上的内容前前后后都看仔细了。超纲题目基本没有。
#
# 2. 统计学习题集有多大的价值？
# 考试题目很少有上面的习题，但是如果把上面的题目都融会贯通了那考试应该也就没 多大问题了。所以建议把统计学多选题上课讲过的题目复习一遍。如果学有余力或者想 考A的同学强烈建议作一遍后面部分的复习题。
#
# 3. 有哪些题型及应对策略？
#     - 判断题和选择题:没什么好说的。
#     - 简答题：  会考一下基础的概念性的问题。比方说一类错误二类错误，t分布特点之类的。相关与回归异同（考过的）。
#     - 问答题：  考过一个求均数的题。给你数据资料，让你分析用什么方法算均数，然后计算。计算量 不大。至于很多人担心的会不会考计算很烦的题。完全不必要考虑这种可能。印象中最 后一个题是考卡方检验。他帮你算好了然后问你这样算对不对。其考点是卡方检验的一 些注意事项。
#
# ---
#
# 我觉得这些知识点比较重要（仅供参考）
# 1. 各种求均数的方法，不光是背公式，还要搞清楚什么情况下适合用这种方法而不是另
# 一种。
# 2. 正态分布的特点
# 3. t分布曲线特点
# 4. 配对资料的比较（好像也考过大题的)
# 5. 应用相对数的注意事项
# 6. 卡方检验的注意事项
# 7. 相关与回归的异同及其注意事项
# 8. 其他的这么长时间了忘得差不多了。。。
#
# ---
#
# 虽然题目出的很恶心，也实在没有心情去说些什么，但是考虑到后来人，还是吧题目发上 来了。 这次考试是我大学三年来第一次发现没有人提前交卷的考试，原因就在于考了一些上课没 有讲过的内容，而我们自然也没有看过 方差分析是没有讲过的，但是问答题问了一道方差齐性的问题，就我个人而言，是不知道 方差齐性的概念的。10分是彻底没有了，同时成组的t设计，课本似乎找不到，但试卷也涉 及了。 判断题打了很多勾，每打一个就心跳一下，做完判断题信心已经彻底的被毁灭了，唯一欣 慰的是应用题不算太难。 留给下一界的人就是：上课没讲到的也要看，同时别太信任最后一节的划重点。 这次出来的唯一想法：及格就行。
#
# ---
# 判断，选择参考书后习题和宝典
