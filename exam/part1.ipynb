# %% [markdown]
# # 卫生统计学 1 历年题

# %% [markdown]
# ## 统计
#
# ---

# %% [markdown]
# ## 目录
#
# - [01级临五](#01级临五)
# - [02级临五](#02级临五)
# - [03级临五](#03级临五)
# - [09级临八](#09级临八)
# - [11级临五](#11级临五)
# - [12级临五](#12级临五)
# - [13级临八](#13级临八)

# %% [markdown]
# ## 12级临五
# ### 判断
#
# <details>
#     <summary>标准差是关于观察值的变化大小，标准误是关于总体均数的变化大小</summary>
#     <p>x <a href="../notes/4%20Sampling.ipynb#标准误-SE">标准误</a>是样本均数的变化大小。</p>
# </details>
#
# <details>
#     <summary>标准误是一类特殊的标准差</summary>
#     <p>√</p>
# </details>
#
# <details>
#     <summary>增大样本量会减少一类错误，但可能增大二类错误</summary>
#     <p>（×）和二类错误无关。</p>
# </details>
#
# <details>
#     <summary>若一个资料经过对数变换后近似对称分布，对其应取算术均数</summary>
#     <p>（×）对数均数。</p>
# </details>
#
# <details>
#     <summary>只要样本量足够大，虽然总体呈偏态分布，其样本均数也呈正态分布</summary>
#     <p>（√）<a href="../notes/4%20Sampling.ipynb#中心极限定理-CLT">中心极限定理</a></p>
# </details>
#
# <details>
#     <summary>某医生用了一个药治疗急性结肠炎，10个人里有8个人有效，所以认为有效率为80%</summary>
#     <p>（×）emmmmm.</p>
# </details>
#
# <details>
#     <summary>主要从非计算题部分出</summary>
#     <p></p>
# </details>
#
# ### 选择题
#
# <details>
#     <summary>直方图用于描述</summary>
#     <p>样本频数分布，其他选项有频数随变量取值的变化、每部分的构成比等</p>
# </details>
#
# <details>
#     <summary>关于某疾病患病率的选项正确的是（n个人里患病人数服从二项分布（n，π），其他选项有患病率服从N（nπ，nπ（1-π））等）</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>统计推断常包括哪两方面的内容</summary>
#     <p>（区间估计和假设检验）</p>
# </details>
#
# <details>
#     <summary>四格表数据中两个阳性率的比较，如果p>0.05,应该下什么结论</summary>
#     <p>总体均数没有差别，其他选项有样本均数有差别，样本均数无差别</p>
# </details>
#
# <details>
#     <summary>如果odds定义为发生率/未发生率，吸烟者肺癌发病率为p1，不吸烟者肺癌发病率为p2，
#         问吸烟者肺癌的odds以及吸烟者和非吸烟者肺癌的odds的比为多少</summary>
#     <p>（p1/(1-p1)，p1*(1-p2)/p2*(1-p1)）</p>
# </details>
#
# <details>
#     <summary>四个表中若n1+n2$<$40，问用什么检验</summary>
#     <p>（Fisher检验，其他有卡方、校正卡方等）</p>
# </details>
#
# <details>
#     <summary>下列哪个率中人群的年龄分布对其没有影响（婴儿死亡率，其他有粗出生率、死亡率、癌症患病率等）</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>一个偏态分布要求参考值范围，值只有偏小才有实际意义，问95%的参考值应取（P5，其他选项有P2.5和P97.5，P95等）</summary>
#     <p></p>
# </details>
#
# ### 简答题
#
# <details>
#     <summary>标准化的意义和基本思想</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>辨析题：求出总体均数的95%可信区间，表明总体参数有95%可能落在区间里</summary>
#     <p> 应该是不正确的。这个区间包含总体均数这个事件的正确性是95%。总体均数本身并不是一个随机变量，而是一个确定的值。</p>
# </details>
#
# <details>
#     <summary>研究者调查了100个结肠癌患者，发现80%都有长期饮酒史，于是得出结论长期饮酒是结肠癌的病因。
#         请问这个结论是否正确，为什么？</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>假设检验的目的是什么？请写出假设检验的步骤，可以结合具体的例子。</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>配对设计中，配对t检验的资料是否可以用成组t检验的方法来分析？为什么？</summary>
#     <p></p>
# </details>
#
# ### 计算题
# <details>
#     <summary>某社区110个成年健康男子的舒张压测量数据，以频数表方式给出。
#         <br />问：① x的均数，s，标准误，M，CV分别是多少
#         <br />②理论上95%的成年健康男子的舒张压范围
#         <br />③该社区成年健康男子的平均舒张压范围是多少
#         <br />④若某男子的舒张压为88mmHg，请问该如何评价</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>对12个人测量了服用某降血脂药前后的血甘油三酯的值。问使用该药前后的血甘油三酯值有没有差异。给出了几个t界值。（一道配对t检验的题目）</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>对某个疾病分别用中医和西医方法进行治疗，对疗效统计了一张四格表。问两种疗法的有效率是否有差别。
#         <br />有效	无效	合计
#         <br />西医	14	4	18
#         <br />中医	8	10	18
#         <br />合计	22	14	36
# <br />（一道Fisher精确概率检验的题目，注意有两个18，数据是对称的，如果注意到了能减少很多计算量</summary>
#     <p></p>
# </details>

# %% [markdown]
# ## 13级临八
# <br />
# <details>
#     <summary>P80指80%观察值小于它</summary>
#     <p>错误。小于等于</p>
# </details>
#
# <details>
#     <summary>小概率事件在一次试验中一定不可能发生</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>能用四格表卡方检验的也能用fisher</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>加大样本量，阿尔法不变，则H0成立情况下把它拒绝掉的可能性减小，对吗</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>一个医生希望新药更牛逼，就用了单侧检验，可以吗</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>用AST和ALT分别对每个病人做了阴阳性测试，问阳性率有没有差别</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>给了乙肝，饮酒，过往乙肝患者接触史的一些数据，直接问你能分析些什么，第二小题就让你写具体怎么分析</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>用了某药以后某病患者PEF值的升高，LZ用了配对T检验；然后又问根据设计原则怎么改进 LZ加了对照</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>手指敲桌子，问总体 设计方法（然而并不知道完全随机和随机对照写哪个）数据类型 观察指标</summary>
#     <p></p>
# </details>
#
# <hr />

# %% [markdown]
# ## 11级临五
# <br />
# <details>
#     <summary>说明试验设计中为何要遵循随机对照原则</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>总体均数的95%置信区间表明总体参数有95%的可能落在区间里，辨析这句话</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>为什么P＞0.05时不能接受H0</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>假设检验的两类错误含义和关系</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>某研究单位想要知道新配方的不良反应率是否低于原配方。
#         已知原配方的不良反应率0.01，现在有200名患者采用新配方治疗，无人产生不良反应。
#         问新配方的不良反应率是否低于原配方。</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>给出了t分布自由度34-37的界值表，应用题</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>Fisher检验应用题</summary>
#     <p></p>
# </details>
#
# <hr />

# %% [markdown]
# ## 09级临八
# <br />
# <details>
#     <summary>给出假设检验的一般步骤，说出假设检验的原理和基本思想</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>说说医学正常值和可信区间的有神马区别</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>考poisson分布，二项分布和正态分布之间的关系</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>随机区组设计里，若分2组，f检验能不能代替t检验，说理由</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>给一个实例，说明为什么用单侧检验是不合理的</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>5个10ml样本 培养后菌落分别为14、15、16、17、19给出1ml样本平均细菌数的95%可信区间</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>2样本间t检验的一般步骤</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>考了一个单因素方差分析的一般步骤</summary>
#     <p></p>
# </details>
#
# <hr />
# 判断，选择参考书后习题和宝典
#
# <hr />

# %% [markdown]
# ## 03级临五
# <br />
# <details>
#     <summary>解释：抽样误差，检验效能</summary>
#     <p>a</p>
# </details>
#
# <details>
#     <summary>两个独立样本（符合t检验的要求）进行t检验，得到t＝5，
#     已知t远远大于t界值表中0.01所对应的数值，能否认为是一个小概率事件，为什么？</summary>
#     <p>a</p>
# </details>
#
# <details>
#     <summary>判断三个独立样本差别是否有统计学意义，某同学对其进行两两t检验,
#     (样本都符合检验条件), 问: 这种做法有什么缺陷？应当如何改进？</summary>
#     <p>a</p>
# </details>
#
# <details>
#     <summary>同一计量资料，用方差分析和秩和检验得到的结果不同，应该选择那一种方法？</summary>
#     <p>a</p>
# </details>
#
# <details>
#     <summary>对于等级资料，为什么不能用卡方检验，而应该选择秩和检验？</summary>
#     <p>a</p>
# </details>
#
# <details>
#     <summary>配对t检验，成组t检验以及大样本的u检验是否需要满足方差齐性？为什么？</summary>
#     <p>a</p>
# </details>
#
# <details>
#     <summary>山区和平原地区20到30岁男性红细胞的水平是否有差别.
#         条件：两者的均数，标准差，以及例数都给出
#         求：变异系数，正常值范围，两者的红细胞是否有差别</summary>
#     <p>a</p>
# </details>
#
#
# <details>
#     <summary>两个独立样本的t检验（要吧公式背熟）</summary>
#     <p>a</p>
# </details>
#
# <details>
#     <summary>配对四个表资料的卡方检验，给出一组数据，要会制成配对的四个表</summary>
#     <p>a</p>
# </details>
#
# <details>
#     <summary>观察宫内放置节育环对妇女的影响，
#         问：题中的方法是否有缺陷？为什么？
#         如果让你来设计试验，应该怎么做？</summary>
#     <p>a</p>
# </details>
#
# <hr />
#
# 虽然题目出的很恶心，也实在没有心情去说些什么，但是考虑到后来人，还是吧题目发上 来了。 这次考试是我大学三年来第一次发现没有人提前交卷的考试，原因就在于考了一些上课没 有讲过的内容，而我们自然也没有看过 方差分析是没有讲过的，但是问答题问了一道方差齐性的问题，就我个人而言，是不知道 方差齐性的概念的。10分是彻底没有了，同时成组的t设计，课本似乎找不到，但试卷也涉 及了。 判断题打了很多勾，每打一个就心跳一下，做完判断题信心已经彻底的被毁灭了，唯一欣 慰的是应用题不算太难。 留给下一界的人就是：上课没讲到的也要看，同时别太信任最后一节的划重点。 这次出来的唯一想法：及格就行。
#
# <hr />

# %% [markdown]
# ## 02级临五
# <br />
#
# 1. 统计学怎么复习？
# 以本为本，课本上的内容前前后后都看仔细了。超纲题目基本没有。
# 2. 统计学习题集有多大的价值？
# 考试题目很少有上面的习题，但是如果把上面的题目都融会贯通了那考试应该也就没 多大问题了。所以建议把统计学多选题上课讲过的题目复习一遍。如果学有余力或者想 考A的同学强烈建议作一遍后面部分的复习题。
# 3.  有哪些题型及应对策略？
#     - 判断题和选择题:没什么好说的。
#     - 简答题：  会考一下基础的概念性的问题。比方说一类错误二类错误，t分布特点之类的。相关与回归异同（考过的）。
#     - 问答题：  考过一个求均数的题。给你数据资料，让你分析用什么方法算均数，然后计算。计算量 不大。至于很多人担心的会不会考计算很烦的题。完全不必要考虑这种可能。印象中最 后一个题是考卡方检验。他帮你算好了然后问你这样算对不对。其考点是卡方检验的一 些注意事项。
#
# 我觉得这些知识点比较重要(仅供参考):
# 1. 各种求均数的方法，不光是背公式，还要搞清楚什么情况下适合用这种方法而不是另一种。
# 2. 正态分布的特点
# 3. t分布曲线特点
# 4. 配对资料的比较（好像也考过大题的)
# 5. 应用相对数的注意事项
# 6. 卡方检验的注意事项
# 7. 相关与回归的异同及其注意事项
# 8. 其他的这么长时间了忘得差不多了。。。
#
# <hr />

# %% [markdown]
# ## 01级临五
# <br />
# <details>
#     <summary>标准差与标准误的联系与区别</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>I类错误与II类错误的联系与区别</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>线形相关与线形回归的联系与区别</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>一道配对T检验的大题</summary>
#     <p></p>
# </details>
#
# <details>
#     <summary>一道一致性检验的大题</summary>
#     <p></p>
# </details>
# <hr />

# %% [markdown]
# [yzmiao14@fudan.edu.cn](mailto:yzmiao14@fudan.edu.cn)
